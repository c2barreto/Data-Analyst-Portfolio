# %% [markdown]
# <h1 align=center><font size = 5>Chicago: Exploring Schools, Crime, & Socioeconomic Indicators With SQL</font></h1>

# %% [markdown]
# # Objectives
#
# 1. Understand 3 Chicago datasets
# 1. Load the 3 datasets into 3 tables in a Db2 database
# 1. Execute SQL queries related to the Datasets

# %% [markdown]
# ## About the Data
# The following three datasets will be used and are available on the city of Chicago's Data Portal:
# 1. <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2">Socioeconomic Indicators in Chicago</a>
# 1. <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t">Chicago Public Schools</a>
# 1. <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A snapshot of this dataset will be used which can be downloaded from:
# https://ibm.box.com/shared/static/05c3415cbfbtfnr2fx4atenb2sd361ze.csv
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2
#
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A snapshot of this dataset will be used which can be downloaded from:
# https://ibm.box.com/shared/static/f9gjvj1gjmxxzycdhplzt01qtz0s7ew7.csv
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t
#
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# This dataset is quite large - over 1.5GB in size with over 6.5 million rows. A snapshot of this dataset will be used which can be downloaded from:
# https://ibm.box.com/shared/static/svflyugsr9zbqy5bmowgswqemfpm1x7f.csv
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2

# %% [markdown]
# ### Connecting to the database
# Loading the SQL extension and establish a connection with the DB2 database where these datasets have been uploaded too.

# %%
# %%capture
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name
# %sql ibm_db_sa://xch49725:w4k%2Bdjpqw9kv5gms@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB

# %% [markdown]
# ##### The total number of crimes recorded in the CRIME table

# %%
# Rows in Crime table
# %sql SELECT COUNT(*) AS TOTAL_NUMBER_CRIMES FROM CHICAGO_CRIME_DATA;
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %% [markdown]
# ##### Retrieving the first 10 rows from the CRIME table

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA LIMIT 10;
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(3512276, 'HK587712', datetime.datetime(2004, 8, 28, 17, 50, 56), '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, '6', 1155838, 1873050, 2004, datetime.datetime(2018, 2, 10, 15, 50, 1), Decimal('41.80744050'), Decimal('-87.70395585'), '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', datetime.datetime(2004, 6, 26, 12, 40), '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, '6', 1152206, 1906127, 2004, datetime.datetime(2018, 2, 28, 15, 56, 25), Decimal('41.89827996'), Decimal('-87.71640551'), '(41.898279962, -87.716405505)'),
# ...

# %% [markdown]
# ##### Number of crimes involving an arrest

# %%
# %%sql
# SELECT COUNT(ID) AS CRIME_WITH_ARREST
# FROM CHICAGO_CRIME_DATA
# WHERE ARREST = 'TRUE';
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('163'),)]

# %% [markdown]
# ##### Unique types of crimes that have been recorded at gas stations

# %%
# %%sql
# SELECT DISTINCT(PRIMARY_TYPE), LOCATION_DESCRIPTION
# FROM CHICAGO_CRIME_DATA
# WHERE LOCATION_DESCRIPTION = 'GAS STATION';
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('CRIMINAL TRESPASS', 'GAS STATION'),
#  ('NARCOTICS', 'GAS STATION'),
#  ('ROBBERY', 'GAS STATION'),
#  ('THEFT', 'GAS STATION')]

# %% [markdown]
# ##### Listing all Community Areas whose names start with the letter ‘B’  In the CENUS_DATA table

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME
# FROM CENSUS_DATA
# WHERE COMMUNITY_AREA_NAME LIKE 'B%' ;
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Belmont Cragin',),
#  ('Burnside',),
#  ('Brighton Park',),
#  ('Bridgeport',),
#  ('Beverly',)]

# %% [markdown]
# ##### Schools in Community Areas 10 to 15 that are healthy school certified.

# %%
# %%sql
# SELECT NAME_OF_SCHOOL, COMMUNITY_AREA_NUMBER, HEALTHY_SCHOOL_CERTIFIED
# FROM CHICAGO_PUBLIC_SCHOOLS
# WHERE HEALTHY_SCHOOL_CERTIFIED = 'Yes' AND (COMMUNITY_AREA_NUMBER BETWEEN 10 AND 15);
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Rufus M Hitch Elementary School', 10, 'Yes')]

# %% [markdown]
# ##### The average school Safety Score

# %%
# %%sql
# SELECT AVG(SAFETY_SCORE) AS AVERAGE_SCHOOL_SAFETY_SCORE
# FROM CHICAGO_PUBLIC_SCHOOLS ;
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('49.504873'),)]

# %% [markdown]
# ##### The top 5 Community Areas by average College Enrollment [number of students]

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, AVG(COLLEGE_ENROLLMENT) AS AVERAGE_COLLEGE_ENROLLMENT
# FROM CHICAGO_PUBLIC_SCHOOLS
# GROUP BY COMMUNITY_AREA_NAME
# ORDER BY AVERAGE_COLLEGE_ENROLLMENT DESC
# FETCH FIRST 5 ROWS ONLY ;
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('ARCHER HEIGHTS', Decimal('2411.500000')),
#  ('MONTCLARE', Decimal('1317.000000')),
#  ('WEST ELSDON', Decimal('1233.333333')),
#  ('BRIGHTON PARK', Decimal('1205.875000')),
#  ('BELMONT CRAGIN', Decimal('1198.833333'))]

# %% [markdown]
# ##### Determining which Community Area has the least value for school Safety Score

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, SAFETY_SCORE
# FROM CHICAGO_PUBLIC_SCHOOLS
# WHERE SAFETY_SCORE = (SELECT MIN(SAFETY_SCORE) FROM CHICAGO_PUBLIC_SCHOOLS) ;
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('WASHINGTON PARK', 1)]

# %% [markdown]
# ##### Per Capita Income of the Community Area which has a school Safety Score of 1

# %%
# %%sql
# SELECT CD.COMMUNITY_AREA_NAME, CD.PER_CAPITA_INCOME, CPS.SAFETY_SCORE
# FROM CENSUS_DATA AS CD, CHICAGO_PUBLIC_SCHOOLS AS CPS
# WHERE CD.COMMUNITY_AREA_NUMBER = CPS.COMMUNITY_AREA_NUMBER
# AND CPS.SAFETY_SCORE = 1;
# Out:
#  * ibm_db_sa://xch49725:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Washington Park', 13785, 1)]
